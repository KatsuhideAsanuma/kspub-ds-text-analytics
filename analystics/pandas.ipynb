# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %%
s1=pd.Series([1,2,3])

# %%
s1
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
iris=load_iris()
X_iris=iris.data
Y_iris=iris.target

# %%
df=pd.DataFrame(data=X_iris,columns=iris.feature_names)
series1=pd.Series(data=[iris.target_names[i] for i in iris.target],name="species")
df=pd.concat([df,series1],axis=1)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
df.mean()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_4376/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64

# %%
df[df.columns[0]].count()
# Out:
# 150

# %%
df[df.columns[0]].sum()
# Out:
# 876.5

# %%
df[df.columns[0]].sum()/df[df.columns[0]].count()
# Out:
# 5.843333333333334

# %%
df_2=df[["sepal length (cm)","sepal width (cm)"]]
df_2
# Out:
#      sepal length (cm)  sepal width (cm)
# 0                  5.1               3.5
# 1                  4.9               3.0
# 2                  4.7               3.2
# 3                  4.6               3.1
# 4                  5.0               3.6
# ..                 ...               ...
# 145                6.7               3.0
# 146                6.3               2.5
# 147                6.5               3.0
# 148                6.2               3.4
# 149                5.9               3.0
#
# [150 rows x 2 columns]

# %%
df_1=df[df.columns[:2]]
df_1
# Out:
#      sepal length (cm)  sepal width (cm)
# 0                  5.1               3.5
# 1                  4.9               3.0
# 2                  4.7               3.2
# 3                  4.6               3.1
# 4                  5.0               3.6
# ..                 ...               ...
# 145                6.7               3.0
# 146                6.3               2.5
# 147                6.5               3.0
# 148                6.2               3.4
# 149                5.9               3.0
#
# [150 rows x 2 columns]

# %%
df[:5]
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
df['species'].head(10)
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# 5    setosa
# 6    setosa
# 7    setosa
# 8    setosa
# 9    setosa
# Name: species, dtype: object

# %%
df[['sepal length (cm)','petal length (cm)']].head(15)
# Out:
#     sepal length (cm)  petal length (cm)
# 0                 5.1                1.4
# 1                 4.9                1.4
# 2                 4.7                1.3
# 3                 4.6                1.5
# 4                 5.0                1.4
# 5                 5.4                1.7
# 6                 4.6                1.4
# 7                 5.0                1.5
# 8                 4.4                1.4
# 9                 4.9                1.5
# 10                5.4                1.5
# 11                4.8                1.6
# 12                4.8                1.4
# 13                4.3                1.1
# 14                5.8                1.2

# %%
df.iloc[1]
# Out:
# sepal length (cm)       4.9
# sepal width (cm)          3
# petal length (cm)       1.4
# petal width (cm)        0.2
# species              setosa
# Name: 1, dtype: object

# %%
df.iloc[1,1]
# Out:
# 3.0

# %%
df.iloc[0:5,0:2]
# Out:
#    sepal length (cm)  sepal width (cm)
# 0                5.1               3.5
# 1                4.9               3.0
# 2                4.7               3.2
# 3                4.6               3.1
# 4                5.0               3.6

# %%
df.loc[5]
# Out:
# sepal length (cm)       5.4
# sepal width (cm)        3.9
# petal length (cm)       1.7
# petal width (cm)        0.4
# species              setosa
# Name: 5, dtype: object

# %%
df.loc[1:5,['sepal width (cm)','petal width (cm)']]
# Out:
#    sepal width (cm)  petal width (cm)
# 1               3.0               0.2
# 2               3.2               0.2
# 3               3.1               0.2
# 4               3.6               0.2
# 5               3.9               0.4

# %%
df['my_column']=np.random.rand(len(df.index))

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species  my_column
# ...

# %%
del df['my_column']

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
df_2=df.assign(my_column=np.random.rand(len(df.index)),my_column2=np.random.rand(len(df.index)))

# %%
df_2
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
df_3=df_2.drop('my_column2',axis=1)
df_3
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species  my_column
# ...

# %%
columns=pd.Series(iris.feature_names).append(pd.Series(['species']))
new_row=pd.DataFrame([[1,1,1,1,'setosa']],columns=columns)
new_row
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  1                 1                  1                 1
#
#   species
# 0  setosa

# %%
new_df=df.append(new_row,ignore_index=True)
new_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
# 150                1.0               1.0                1.0               1.0
#
#        species
# 0       setosa
# ...

# %%
df[(df['sepal length (cm)']>7.0)&(df['sepal width (cm)']<3.0)]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 107                7.3               2.9                6.3               1.8
# 118                7.7               2.6                6.9               2.3
# 122                7.7               2.8                6.7               2.0
# 130                7.4               2.8                6.1               1.9
#
#        species
# 107  virginica
# 118  virginica
# 122  virginica
# 130  virginica

# %%
df.sort_values(['sepal width (cm)','sepal length (cm)'],ascending=False)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 15                 5.7               4.4                1.5               0.4
# 33                 5.5               4.2                1.4               0.2
# 32                 5.2               4.1                1.5               0.1
# 14                 5.8               4.0                1.2               0.2
# 5                  5.4               3.9                1.7               0.4
# ..                 ...               ...                ...               ...
# 41                 4.5               2.3                1.3               0.3
# 68                 6.2               2.2                4.5               1.5
# 62                 6.0               2.2                4.0               1.0
# 119                6.0               2.2                5.0               1.5
# 60                 5.0               2.0                3.5               1.0
#
#         species
# ...

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
concat_df=pd.concat([df[:5],df[-5:]])
concat_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ...

# %%
pd.concat([df.loc[:,['sepal length (cm)']],df.loc[:,['species']]],axis=1)
# Out:
#      sepal length (cm)    species
# 0                  5.1     setosa
# 1                  4.9     setosa
# 2                  4.7     setosa
# 3                  4.6     setosa
# 4                  5.0     setosa
# ..                 ...        ...
# 145                6.7  virginica
# 146                6.3  virginica
# 147                6.5  virginica
# 148                6.2  virginica
# 149                5.9  virginica
#
# [150 rows x 2 columns]

# %%
sepal_len=pd.concat([df.loc[[0,51,101],['sepal length (cm)']],df.loc[[0,51,101],['species']]],axis=1)
sepal_wid=pd.concat([df.loc[[0,51,101],['sepal width (cm)']],df.loc[[0,51,101],['species']]],axis=1)
sepal=pd.merge(sepal_len,sepal_wid,on='species')
sepal
# Out:
#    sepal length (cm)     species  sepal width (cm)
# 0                5.1      setosa               3.5
# 1                6.4  versicolor               3.2
# 2                5.8   virginica               2.7

# %%
df.groupby('species')

# %%
setosa=df.groupby('species').get_group('setosa')

# %%
setosa
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# ...
